# %% [markdown]
# # Il mio primo notebook
#
# Esercizio della Lezione 1, corso B8. Sostituire questo titolo con uno a scelta.

# %% [markdown]
# In questo notebook si esegue un primo calcolo con Python, per prendere confidenza con le celle di codice e le celle di testo.
#
# Modificare questa cella con una breve descrizione di cosa contiene il notebook.

# %%
# Prima cella di codice: definire qui alcune variabili, per esempio su di sé
# nome = "..."
# eta = ...

# %%
# Seconda cella di codice: un piccolo calcolo a partire dalle variabili precedenti
# per esempio una somma, una conversione tra unita' di misura, o un'altra quantita' derivata

# %%
# Terza cella di codice: stampare il risultato con print()
